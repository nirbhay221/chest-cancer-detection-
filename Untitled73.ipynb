# %%
import tensorflow as tf
import numpy as np
import zipfile as zipfile 
import matplotlib.pyplot as plt
import os

# %%
local_dir = '/content/valid.zip'
zip_ref = zipfile.ZipFile(local_dir,'r')
zip_ref.extractall('/tmp/')
zip_ref.close()

# %%
local_dir = '/content/test.zip'
zip_ref = zipfile.ZipFile(local_dir,'r')
zip_ref.extractall('/tmp/')
zip_ref.close()

# %%
local_dir = '/content/train.zip'
zip_ref = zipfile.ZipFile(local_dir,'r')
zip_ref.extractall('/tmp/')
zip_ref.close()

# %%
train_dir = '/tmp/train/'
train_adeno_dir = os.path.join(train_dir,'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib')
train_large_cell_dir = os.path.join(train_dir,'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa')
train_normal_dir= os.path.join(train_dir,'normal')
train_squamous_cell_dir= os.path.join(train_dir,'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa')

# %%
valid_dir = '/tmp/valid/'
val_adeno_dir=os.path.join(valid_dir,'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib')
val_large_cell_dir=os.path.join(valid_dir,'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa')
val_normal_dir=os.path.join(valid_dir,'normal')
val_squamous_cell_dir=os.path.join(valid_dir,'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa')

# %%
test_dir = '/tmp/test/'
test_adeno_dir=os.path.join(test_dir,'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib')
test_large_cell_dir=os.path.join(test_dir,'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa')
test_normal_dir=os.path.join(test_dir,'normal')
test_squamous_cell_dir=os.path.join(test_dir,'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa')

# %%
adeno_files = os.listdir(train_adeno_dir)
large_cell_files= os.listdir(train_large_cell_dir)
normal_files =os.listdir(train_normal_dir)
squamous_cell_files=os.listdir(train_squamous_cell_dir)

train_files = os.listdir(train_dir)
print(train_files)
# Out:
# ['squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa', 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa', 'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib', 'normal']

# %%
print(adeno_files)
import matplotlib.image as mpimg
# Out:
# ['000021 (8).png', '000119 (4).png', '000054 (7).png', '000050 (5).png', 'ad3.png', '000063 (5).png', '000067 (10).png', '000118 (4).png', '000032 (8).png', '000119 (6).png', '000099 (7).png', '000022 (2).png', '000058 (5).png', '000086 (8).png', '000020 (5).png', '000025 (6).png', '000041 (4).png', '000027 (6).png', '000023 (7).png', '000091 (3).png', '000029 (9).png', '000023 (9).png', '000046 (5).png', '000016 (9).png', '000029 (5).png', '000040 (5).png', '000050 (3).png', '000048 (8).png', '000084 (3).png', '000031 (3).png', '000121 (9).png', '000005 (9).png', '000040 (3).png', '000102 (3).png', '000069 (6).png', '000008 (10).png', '000051 (4).png', '000040 (10).png', '000077 (6).png', 'ad6.png', '000019 (5).png', '000035 (5).png', '000122.png', '000068 (10).png', '000067.png', '000024 (10).png', '000121 (10).png', '000027 (4).png', '000106 (8).png', '000080 (10).png', '000104 (4).png', '000059 (7).png', '000100 (10).png', '000029 (4).png', 'ad5.png', '000091 (7).png', '000056 (7
# ...

# %%
pic_index= 2
next_adeno=[os.path.join(train_adeno_dir,fname) for fname in adeno_files[pic_index-2:pic_index]]
next_large_cell=[os.path.join(train_large_cell_dir,fname) for fname in large_cell_files[pic_index-2:pic_index]]
next_normal= [os.path.join(train_normal_dir,fname) for fname in normal_files[pic_index-2:pic_index]]
next_squamous_cell=[os.path.join(train_squamous_cell_dir,fname) for fname in squamous_cell_files[pic_index-2:pic_index]]

# %%
for i,img_path in  enumerate(next_adeno+next_large_cell+next_normal+next_squamous_cell):
  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.axis('Off')
  plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255.,rotation_range=40,zoom_range = 0.2,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.2,fill_mode='nearest',horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255.)

# %%
train_data_generator = train_datagen.flow_from_directory(train_dir,target_size=(150,150),class_mode='categorical',batch_size=32)
valid_data_generator= test_datagen.flow_from_directory(valid_dir,target_size=(150,150),class_mode='categorical',batch_size=32)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(128,(3,3),input_shape=(150,150,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0.9),
                                    tf.keras.layers.Dense(512,activation='relu'),
                                    
                                    tf.keras.layers.Dense(4,activation='softmax')
                                    
                                    

])

# %%
model.compile(loss= 'categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'] )

# %%
history=model.fit(train_data_generator,epochs=200,validation_data=valid_data_generator)
# Out:
# Epoch 1/200
#  4/20 [=====>........................] - ETA: 53s - loss: 0.7524 - accuracy: 0.6797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-7ed29e28221e> in <module>()
# ----> 1 history=model.fit(train_data_generator,epochs=200,validation_data=valid_data_generator)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
acc= history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs =range(len(acc))
plt.plot(epochs,acc,'r',label='accuracy')
plt.plot(epochs,val_acc,'b',label='validation_accuracy')
plt.title('accuracy and validation accuracy')
plt.show()
plt.plot(epochs,loss,'r',label='loss')
plt.plot(epochs,val_loss,'b',label='validation_loss')
plt.title('loss and validation loss')
plt.show()
